# %% [markdown]
# **Importing dependecies**

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# **----- DATA ANALYSIS & PRE PROCESSING-----**

# %% [markdown]
# **Loading the dataset and initial data analysis**

# %%
dataset = pd.read_csv('dataset.csv')  #reading the dataset

# %%
dataset.head()  #gives 1st 5 rows
# Out:
#    hours  age  internet  marks
# 0   6.83   15         1  78.50
# 1   6.56   16         0  76.74
# 2    NaN   17         1  78.68
# 3   5.67   18         0  71.82
# 4   8.67   19         1  84.19

# %%
dataset.tail()  #gives last 5 rows
# Out:
#      hours  age  internet  marks
# 196   8.56   19         1  84.68
# 197   8.94   20         1  86.75
# 198   6.60   15         1  78.05
# 199   8.35   16         1  83.50
# 200   4.15   15         0  81.45

# %%
dataset.info()  #information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   hours     196 non-null    float64
#  1   age       201 non-null    int64
#  2   internet  201 non-null    int64
#  3   marks     201 non-null    float64
# dtypes: float64(2), int64(2)
# memory usage: 6.4 KB

# %%
dataset.describe() #statistical info about the dataset
# Out:
#             hours         age    internet       marks
# count  196.000000  201.000000  201.000000  201.000000
# mean     6.981429   17.467662    0.552239   77.951244
# std      1.266266    1.720523    0.498505    4.919626
# min      4.150000   15.000000    0.000000   68.570000
# 25%      5.757500   16.000000    0.000000   73.400000
# 50%      7.110000   17.000000    1.000000   77.770000
# 75%      8.082500   19.000000    1.000000   82.300000
# max      8.990000   20.000000    1.000000   86.990000

# %%
dataset.isnull().sum() #Checking for null values
# Out:
# hours       5
# age         0
# internet    0
# marks       0
# dtype: int64

# %%
dataset.shape
# Out:
# (201, 4)

# %% [markdown]
# **Filling the missing values with Mean**

# %%
dataset['hours'] = dataset['hours'].fillna(dataset.hours.mean())

# %% [markdown]
# **Analysis of above opearation**

# %%
dataset.isnull().sum() #null values cleared
# Out:
# hours       0
# age         0
# internet    0
# marks       0
# dtype: int64

# %% [markdown]
# **Dividing the data into X and Y**

# %%
X = dataset.iloc[:, :-1] #taking independent columns to X
Y = dataset['marks'] #taking dependent column to Y

# %%
print(X)
# Out:
#         hours  age  internet
# 0    6.830000   15         1
# 1    6.560000   16         0
# 2    6.981429   17         1
# 3    5.670000   18         0
# 4    8.670000   19         1
# ..        ...  ...       ...
# 196  8.560000   19         1
# 197  8.940000   20         1
# 198  6.600000   15         1
# 199  8.350000   16         1
# 200  4.150000   15         0
#
# [201 rows x 3 columns]

# %%
print(Y)
# Out:
# 0      78.50
# 1      76.74
# 2      78.68
# 3      71.82
# 4      84.19
#        ...
# 196    84.68
# 197    86.75
# 198    78.05
# 199    83.50
# 200    81.45
# Name: marks, Length: 201, dtype: float64

# %% [markdown]
# **Initializing a model and training it**

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# **Evaluating the model**

# %%
a = [[5.05, 18, 1]]
result = model.predict(a)
print(result)
# Out:
# [70.65194936]
# c:\Users\perug\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
a2 = [[6.36, 18, 0]]
result_a2 = model.predict(a2)
print(result_a2)
# Out:
# [75.62481916]
# c:\Users\perug\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **---- ANOTHER MODEL WITH SPLITTING AND STANDARDIZING THE DATA ----**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=34) #Splitting the data(80% for train, 20% for test)

# %%
print(X_train.shape)  #dimensions of the splitted data
print(X_test.shape)
# Out:
# (160, 3)
# (41, 3)

# %%
print(Y_train.shape)  #dimensions of the splitted data
print(Y_test.shape)
# Out:
# (160,)
# (41,)

# %% [markdown]
# **Scaling the data**

# %%
SC = StandardScaler()
X_train_transformed = SC.fit_transform(X_train)
X_test_transformed = SC.transform(X_test)

# %%
print(X_train_transformed)
# Out:
# [[ 0.53801616  0.92525692  0.85972695]
#  [-1.33735322 -0.80284939  0.85972695]
#  [-0.04535477 -0.22681395  0.85972695]
#  [ 1.3417459   0.92525692  0.85972695]
#  [-1.23181295  1.50129236  0.85972695]
#  [ 0.41623893 -0.80284939  0.85972695]
#  [ 0.47306831  0.34922148 -1.16316   ]
#  [-0.93954759 -0.22681395 -1.16316   ]
#  [ 1.58530037 -0.80284939 -1.16316   ]
#  [ 0.73285974  0.34922148 -1.16316   ]
#  [-1.49160438 -0.80284939  0.85972695]
#  [-1.28864233  1.50129236  0.85972695]
#  [-1.49972287 -0.22681395  0.85972695]
#  [-0.42808322 -0.22681395  0.85972695]
#  [ 1.06571751 -0.80284939 -1.16316   ]
#  [-2.34404501 -1.37888483 -1.16316   ]
#  [ 0.1564475  -0.22681395  0.85972695]
#  [ 1.26867956 -0.22681395 -1.16316   ]
#  [-1.47536742  1.50129236  0.85972695]
#  [ 1.49599706  0.92525692 -1.16316   ]
#  [ 1.23620563  0.92525692  0.85972695]
#  [ 0.55425313  0.34922148  0.85972695]
#  [-1.32923474 -0.22681395  0.85972695]
#  [ 1.53658947 -0.22681395  0.85972695]
#  [ 0.0671442  -1.37888483 -1.16316   ]
#  [-1.01261393  0.92525692 -1.16316   ]
#  [-0.23323964  0.34922148 -1.16316   ]
#  [ 0.22139536 -0.22681395 -1.16316   ]
#  [ 0.57860857 -1.37888483 -1.16316   ]
#  [ 0.22139536  0.34922148  0.85972695]
#  [ 1.41481224  0.34922148 -1.16316   ]
#  [ 1.27679804  0.34922148  0.85972695]
#  [-1.04508786 -0.22681395  0.85972695]
#  [ 0.94394027 -0.80284939 -1.16316   ]
#  [ 0.74097822 -1.37888483  0.85972695]
#  [ 1.06571751 -0.80284939  0.85972695]
#  [-0.69599313  0.34922148  0.85972695]
#  [ 0.68414884  0.34922148 -1.16316   ]
#  [ 1.12254688  0.92525692  0.85972695]
#  [-1.47536742  0.92525692  0.85972695]
#  [ 1.39857528 -1.37888483 -1.16316   ]
#  [ 1.55282644 -0.80284939 -1.16316   ]
#  [-0.35501688  1.50129236  0.85972695]
#  [ 1.48787858 -1.37888483  0.85972695]
#  [ 0.99265117 -0.80284939 -1.16316   ]
#  [ 0.7490967  -0.80284939 -1.16316   ]
#  [-0.24947661  0.34922148 -1.16316   ]
#  [ 1.05759902 -0.22681395  0.85972695]
#  [ 1.52847099  1.50129236  0.85972695]
#  [-0.09522545  0.92525692 -1.16316   ]
#  [-0.97202152 -1.37888483 -1.16316   ]
#  [ 1.04948054  0.34922148 -1.16316   ]
#  [-1.61338162  0.92525692  0.85972695]
#  [-1.44289349  1.50129236  0.85972695]
#  [ 0.30258018 -0.80284939  0.85972695]
#  [ 1.53658947  0.34922148  0.85972695]
#  [ 0.74097822  1.50129236  0.85972695]
#  [-1.21557599 -0.80284939 -1.16316   ]
#  [-1.38606411  0.92525692 -1.16316   ]
#  [-0.8908367   0.92525692  0.85972695]
#  [-1.33735322 -1.37888483  0.85972695]
#  [-0.54174197  0.34922148  0.85972695]
#  [-1.21557599 -1.37888483  0.85972695]
#  [-0.53362348 -0.22681395 -1.16316   ]
#  [ 1.35798286 -1.37888483  0.85972695]
#  [-1.58090769 -1.37888483  0.85972695]
#  [ 1.32550894  0.92525692  0.85972695]
#  [ 0.08338116 -0.80284939  0.85972695]
#  [-1.33735322 -1.37888483 -1.16316   ]
#  [ 0.62731947  0.92525692  0.85972695]
#  [-0.5742159   0.34922148  0.85972695]
#  [-0.54986045  0.92525692 -1.16316   ]
#  [-0.39560929  0.34922148  0.85972695]
#  [ 0.74097822  1.50129236 -1.16316   ]
#  [ 0.61920099  0.92525692  0.85972695]
#  [-1.45913045  0.34922148 -1.16316   ]
#  [-0.08710696  0.92525692  0.85972695]
#  [-1.54031528  1.50129236 -1.16316   ]
#  [-1.58090769 -0.80284939  0.85972695]
#  [-1.20745751 -0.80284939  0.85972695]
#  [ 1.35798286 -1.37888483 -1.16316   ]
#  [ 0.6110825  -1.37888483  0.85972695]
#  [ 0.22139536 -0.80284939  0.85972695]
#  [-0.04535477 -0.22681395 -1.16316   ]
#  [ 1.54470795  1.50129236  0.85972695]
#  [-0.55797893 -0.22681395  0.85972695]
#  [-0.76905947  1.50129236 -1.16316   ]
#  [ 1.13878385  1.50129236  0.85972695]
#  [ 0.12397357  0.34922148 -1.16316   ]
#  [-1.12627268  1.50129236 -1.16316   ]
#  [-0.2981875  -1.37888483 -1.16316   ]
#  [ 1.23620563  1.50129236  0.85972695]
#  [ 0.18080295 -0.80284939  0.85972695]
#  [ 0.40000197  0.34922148 -1.16316   ]
#  [-1.06944331  1.50129236  0.85972695]
#  [-0.21700268 -0.80284939 -1.16316   ]
#  [ 1.49599706 -0.22681395 -1.16316   ]
#  [ 0.85463697 -0.22681395 -1.16316   ]
#  [-0.16829179 -1.37888483  0.85972695]
#  [ 0.8384      0.34922148  0.85972695]
#  [ 1.31739045 -0.22681395 -1.16316   ]
#  [-0.38749081 -0.80284939 -1.16316   ]
#  [ 0.70038581 -0.80284939  0.85972695]
#  [ 1.09819143 -1.37888483  0.85972695]
#  [ 0.66791188 -1.37888483  0.85972695]
#  [-0.64728224  0.92525692  0.85972695]
#  [ 1.03324358 -0.80284939 -1.16316   ]
#  [ 0.52989768  0.92525692  0.85972695]
#  [-0.41996473 -1.37888483 -1.16316   ]
#  [ 0.91146634  0.92525692  0.85972695]
#  [-0.23323964 -0.80284939 -1.16316   ]
#  [ 0.31881714  0.34922148  0.85972695]
#  [-1.54031528  1.50129236 -1.16316   ]
#  [-0.96390304  1.50129236  0.85972695]
#  [-1.15062813 -0.22681395  0.85972695]
#  [ 0.25386929  0.92525692  0.85972695]
#  [-0.05463304 -1.37888483  0.85972695]
#  [ 0.39188348 -1.37888483  0.85972695]
#  [-0.12769938 -1.37888483 -1.16316   ]
#  [-0.04535477 -0.80284939  0.85972695]
#  [-1.32923474 -0.22681395 -1.16316   ]
#  [ 1.02512509 -0.80284939  0.85972695]
#  [-1.35359019  0.92525692  0.85972695]
#  [ 0.66791188 -1.37888483  0.85972695]
#  [-1.33735322  0.92525692  0.85972695]
#  [-0.35501688 -1.37888483  0.85972695]
#  [ 1.36610135  0.92525692  0.85972695]
#  [ 0.12397357 -0.80284939 -1.16316   ]
#  [-1.13439117  0.92525692 -1.16316   ]
#  [ 0.67603036 -0.22681395  0.85972695]
#  [-0.38749081  1.50129236 -1.16316   ]
#  [-1.37794563  0.92525692  0.85972695]
#  [-0.46867563 -1.37888483  0.85972695]
#  [-1.01261393  0.34922148 -1.16316   ]
#  [-1.63773706 -0.80284939  0.85972695]
#  [-1.28052385 -1.37888483 -1.16316   ]
#  [-0.55797893 -1.37888483 -1.16316   ]
#  [ 0.91146634  0.34922148  0.85972695]
#  [ 0.51366072 -0.80284939  0.85972695]
#  [ 0.18080295  1.50129236 -1.16316   ]
#  [ 1.02512509  0.92525692  0.85972695]
#  [ 0.41623893  1.50129236 -1.16316   ]
#  [-0.55797893 -0.22681395 -1.16316   ]
#  [-0.04535477 -1.37888483  0.85972695]
#  [ 0.31069866 -0.22681395  0.85972695]
#  [-1.09379876  0.92525692 -1.16316   ]
#  [ 1.45540465  0.34922148  0.85972695]
#  [ 0.99265117 -1.37888483 -1.16316   ]
#  [-1.47536742  1.50129236 -1.16316   ]
#  [ 1.42293072  1.50129236 -1.16316   ]
#  [ 0.35940956  1.50129236 -1.16316   ]
#  [ 1.1144284  -1.37888483 -1.16316   ]
#  [-0.69599313 -0.80284939 -1.16316   ]
#  [ 1.26867956 -0.80284939  0.85972695]
#  [ 0.05090723  1.50129236 -1.16316   ]
#  [-1.59714465 -0.22681395  0.85972695]
#  [-1.14250965 -0.80284939  0.85972695]
#  [-0.46867563  0.34922148  0.85972695]
#  [-0.04535477 -0.22681395  0.85972695]
#  [ 0.21327688  1.50129236 -1.16316   ]]

# %%
print(X_test_transformed)
# Out:
# [[-0.02215911  0.92525692  0.85972695]
#  [-0.93954759 -0.80284939 -1.16316   ]
#  [ 0.87087393 -1.37888483  0.85972695]
#  [-0.90707367  0.34922148 -1.16316   ]
#  [-0.42808322  1.50129236 -1.16316   ]
#  [ 0.40000197 -0.22681395  0.85972695]
#  [-1.2561684  -1.37888483  0.85972695]
#  [-1.59714465  1.50129236 -1.16316   ]
#  [-0.42808322 -0.22681395 -1.16316   ]
#  [ 1.35798286  0.92525692 -1.16316   ]
#  [-0.36313536  0.92525692 -1.16316   ]
#  [-1.49972287 -0.22681395 -1.16316   ]
#  [ 0.82216304  1.50129236 -1.16316   ]
#  [-0.80965188  0.34922148  0.85972695]
#  [ 0.82216304  0.34922148  0.85972695]
#  [-1.64585554  1.50129236 -1.16316   ]
#  [ 1.3417459  -0.80284939  0.85972695]
#  [ 0.77345215 -0.22681395  0.85972695]
#  [-1.29676081 -0.22681395  0.85972695]
#  [-1.3454717   0.34922148 -1.16316   ]
#  [-1.56467072  0.92525692  0.85972695]
#  [ 1.5690634   1.50129236 -1.16316   ]
#  [-1.11003572  0.34922148 -1.16316   ]
#  [-0.30630598  0.92525692  0.85972695]
#  [ 0.66791188  0.34922148 -1.16316   ]
#  [ 0.18080295  0.34922148  0.85972695]
#  [ 0.93582179 -0.22681395 -1.16316   ]
#  [-1.42665653  0.92525692  0.85972695]
#  [-1.03696938 -0.80284939 -1.16316   ]
#  [ 0.8871109  -1.37888483  0.85972695]
#  [-0.83400733  1.50129236  0.85972695]
#  [-1.01261393 -0.80284939  0.85972695]
#  [-1.28864233 -1.37888483 -1.16316   ]
#  [ 1.39045679  1.50129236 -1.16316   ]
#  [ 0.98453268  0.34922148 -1.16316   ]
#  [-0.16829179 -1.37888483  0.85972695]
#  [ 0.76533366 -0.22681395 -1.16316   ]
#  [-1.56467072  1.50129236  0.85972695]
#  [ 0.84651849 -0.22681395  0.85972695]
#  [-1.58090769 -0.22681395 -1.16316   ]
#  [ 0.70038581  0.34922148 -1.16316   ]]

# %% [markdown]
# **Initializing a model and training it**

# %%
model1 = LinearRegression()
model1.fit(X_train_transformed, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = model1.predict(X_test)
print(y_pred)
# Out:
# [109.97633198 104.94809993 115.13631875 105.08876683 107.76564247
#  112.41798671 103.05474257 101.12538686 107.83131943 117.93236975
#  108.15643788 101.74441846 114.86702694 105.52527434 114.79396447
#  100.84870954 117.78897383 114.53917947 102.78039349 102.59867097
#  101.21488361 119.10941247 103.93594467 108.36238097 114.03466675
#  111.15104646 115.57828431 101.99880267 104.39474529 115.22854452
#  105.34315104 104.41623683 102.98713814 118.09492897 115.83306931
#  109.23386932 114.6099137  101.19299129 114.95419545 101.2832896
#  114.21911829]
# c:\Users\perug\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
b = [[5.05, 18, 1]]
result1 = model.predict(b)
print(result1)
# Out:
# [70.65194936]
# c:\Users\perug\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
b2 = [[6.36, 18, 0]]
result_b2 = model.predict(b2)
print(result_b2)
# Out:
# [75.62481916]
# c:\Users\perug\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
