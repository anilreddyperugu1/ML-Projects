# %% [markdown]
# # **Market Basket Analysis using ECLAT**

# %% [markdown]
# **Importing Dependencies**

# %%
import numpy as np
import pandas as pd
from apyori import apriori

# %% [markdown]
# **---- INITIAL DATA ANALYSIS & PRE PROCESSING ----**

# %%
dataset = pd.read_csv('Groceries_dataset.csv') #reading the dataset

# %%
dataset.head() #gives top 5 rows
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
dataset.shape #dimensions of the dataset
# Out:
# (38765, 3)

# %%
dataset.info() #information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38765 entries, 0 to 38764
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Member_number    38765 non-null  int64
#  1   Date             38765 non-null  object
#  2   itemDescription  38765 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 908.7+ KB

# %%
dataset.describe() #statistical description about the dataset
# Out:
#        Member_number
# count   38765.000000
# mean     3003.641868
# std      1153.611031
# min      1000.000000
# 25%      2002.000000
# 50%      3005.000000
# 75%      4007.000000
# max      5000.000000

# %% [markdown]
# **Creating transactions needed for ECLAT analysis**

# %%
transactions = dataset.groupby(['Member_number', 'Date'])['itemDescription'].apply(list).values.tolist()

# %% [markdown]
# **Analysis of the above operation**

# %%
for i in range(5):
    print(transactions[i])
# Out:
# ['sausage', 'whole milk', 'semi-finished bread', 'yogurt']
# ['whole milk', 'pastry', 'salty snack']
# ['canned beer', 'misc. beverages']
# ['sausage', 'hygiene articles']
# ['soda', 'pickled vegetables']

# %% [markdown]
# **Definig rules and training the model**

# %%
frequent_itemsets = apriori(transactions, min_support=0.001, min_confidence=0.1, min_lift=0.5, min_length=2) #defining thresholds

# %% [markdown]
# **Model Results**

# %%
rules = list(frequent_itemsets) #output
rules
# Out:
# [RelationRecord(items=frozenset({'other vegetables'}), support=0.12210118291786407, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'other vegetables'}), confidence=0.12210118291786407, lift=1.0)]),
#  RelationRecord(items=frozenset({'rolls/buns'}), support=0.11000467820624206, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'rolls/buns'}), confidence=0.11000467820624206, lift=1.0)]),
#  RelationRecord(items=frozenset({'whole milk'}), support=0.15792287642852368, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'whole milk'}), confidence=0.15792287642852368, lift=1.0)]),
#  RelationRecord(items=frozenset({'other vegetables', 'UHT-milk'}), support=0.002138608567800575, ordered_statistics=[OrderedStatistic(items_base=frozenset({'UHT-milk'}), items_add=frozenset({'other vegetables'}), confidence=0.1, lift=0.818992884510126)]),
#  RelationRecord(items=frozenset({'whole milk', 'UHT-milk'}), support=0.0025395976742631824, ordered_statistics=[OrderedStatistic(items_base=frozenset({'UHT-milk'}), items_add=frozenset({'whole milk'}), confidence=0.11875, lift=0.7519493228946255)]),
#  RelationRecord(items=frozenset({'beef', 'whole milk'}), support=0.004678206242063757, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beef'}), items_add=frozenset({'whole milk'}), confidence=0.1377952755905512, lift=0.8725479088706803)]),
#  RelationRecord(items=frozenset({'berries', 'other vegetables'}), support=0.0026732607097507185, ordered_statistics=[OrderedStatistic(items_base=frozenset({'berries'}), items_add=frozenset({'other vegetables'}), confidence=0.12269938650306748, lift=1.0048992447977005)]),
#  RelationRecord(items=frozenset({'berries', 'whole milk'}), support=0.0022722716032881106, ordered_statistics=[OrderedStatistic(items_base=frozenset({'berries'}), items_add=frozenset({'whole milk'}), confidence=0.10429447852760736, lift=0.660414000088273)]),
#  RelationRecord(items=frozenset({'other vegetables', 'beverages'}), support=0.0017376194613379669, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beverages'}), items_add=frozenset({'other vegetables'}), confidence=0.10483870967741936, lift=0.8586215724702932)]),
#  RelationRecord(items=frozenset({'soda', 'beverages'}), support=0.001871282496825503, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beverages'}), items_add=frozenset({'soda'}), confidence=0.11290322580645162, lift=1.1626778855760054)]),
#  RelationRecord(items=frozenset({'whole milk', 'beverages'}), support=0.0019381140145692708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beverages'}), items_add=frozenset({'whole milk'}), confidence=0.11693548387096775, lift=0.7404594351084598)]),
#  RelationRecord(items=frozenset({'bottled beer', 'other vegetables'}), support=0.004678206242063757, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'other vegetables'}), confidence=0.10324483775811208, lift=0.8455678748629617)]),
#  RelationRecord(items=frozenset({'bottled beer', 'whole milk'}), support=0.007150972398583172, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'whole milk'}), confidence=0.15781710914454278, lift=0.9993302598941151)]),
#  RelationRecord(items=frozenset({'whole milk', 'bottled water'}), support=0.007150972398583172, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bottled water'}), items_add=frozenset({'whole milk'}), confidence=0.11784140969162996, lift=0.7461959429605837)]),
#  RelationRecord(items=frozenset({'brown bread', 'whole milk'}), support=0.004477711688832453, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brown bread'}), items_add=frozenset({'whole milk'}), confidence=0.11900532859680285, lift=0.7535661158671016)]),
#  RelationRecord(items=frozenset({'whole milk', 'butter'}), support=0.004678206242063757, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter'}), items_add=frozenset({'whole milk'}), confidence=0.13282732447817835, lift=0.84108982486965)]),
#  RelationRecord(items=frozenset({'candy', 'rolls/buns'}), support=0.0014702933903628951, ordered_statistics=[OrderedStatistic(items_base=frozenset({'candy'}), items_add=frozenset({'rolls/buns'}), confidence=0.10232558139534884, lift=0.9301929978241826)]),
#  RelationRecord(items=frozenset({'candy', 'whole milk'}), support=0.002138608567800575, ordered_statistics=[OrderedStatistic(items_base=frozenset({'candy'}), items_add=frozenset({'whole milk'}), confidence=0.1488372093023256, lift=0.942467694790816)]),
#  RelationRecord(items=frozenset({'whole milk', 'canned beer'}), support=0.006014836596939116, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned beer'}), items_add=frozenset({'whole milk'}), confidence=0.1282051282051282, lift=0.8118211313302299)]),
#  RelationRecord(items=frozenset({'cat food', 'whole milk'}), support=0.001670787943594199, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cat food'}), items_add=frozenset({'whole milk'}), confidence=0.14124293785310735, lift=0.8943792124824568)]),
#  RelationRecord(items=frozenset({'chewing gum', 'whole milk'}), support=0.001670787943594199, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chewing gum'}), items_add=frozenset({'whole milk'}), confidence=0.1388888888888889, lift=0.8794728922744158)]),
#  RelationRecord(items=frozenset({'chewing gum', 'yogurt'}), support=0.001403461872619127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chewing gum'}), items_add=frozenset({'yogurt'}), confidence=0.11666666666666667, lift=1.358508430609598)]),
#  RelationRecord(items=frozenset({'chicken', 'rolls/buns'}), support=0.0028737552629820224, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken'}), items_add=frozenset({'rolls/buns'}), confidence=0.10311750599520385, lift=0.9373920062006289)]),
#  RelationRecord(items=frozenset({'whole milk', 'chicken'}), support=0.003408407404932166, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken'}), items_add=frozenset({'whole milk'}), confidence=0.1223021582733813, lift=0.774442316650277)]),
#  RelationRecord(items=frozenset({'chocolate', 'rolls/buns'}), support=0.002806923745238254, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate'}), items_add=frozenset({'rolls/buns'}), confidence=0.11898016997167138, lift=1.081591909651348)]),
#  RelationRecord(items=frozenset({'chocolate', 'whole milk'}), support=0.0029405867807257902, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate'}), items_add=frozenset({'whole milk'}), confidence=0.12464589235127478, lift=0.789283320885368)]),
#  RelationRecord(items=frozenset({'citrus fruit', 'whole milk'}), support=0.007150972398583172, ordered_statistics=[OrderedStatistic(items_base=frozenset({'citrus fruit'}), items_add=frozenset({'whole milk'}), confidence=0.13459119496855346, lift=0.8522590140983773)]),
#  RelationRecord(items=frozenset({'coffee', 'whole milk'}), support=0.003809396511394774, ordered_statistics=[OrderedStatistic(items_base=frozenset({'coffee'}), items_add=frozenset({'whole milk'}), confidence=0.12050739957716701, lift=0.7630775369755185)]),
#  RelationRecord(items=frozenset({'cream cheese ', 'whole milk'}), support=0.0028737552629820224, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cream cheese '}), items_add=frozenset({'whole milk'}), confidence=0.12146892655367232, lift=0.7691661227349129)]),
#  RelationRecord(items=frozenset({'curd', 'other vegetables'}), support=0.003542070440419702, ordered_statistics=[OrderedStatistic(items_base=frozenset({'curd'}), items_add=frozenset({'other vegetables'}), confidence=0.10515873015873017, lift=0.861242517441204)]),
#  RelationRecord(items=frozenset({'curd', 'whole milk'}), support=0.004143554100113613, ordered_statistics=[OrderedStatistic(items_base=frozenset({'curd'}), items_add=frozenset({'whole milk'}), confidence=0.12301587301587302, lift=0.7789617045859112)]),
#  RelationRecord(items=frozenset({'dessert', 'whole milk'}), support=0.0024059346387756467, ordered_statistics=[OrderedStatistic(items_base=frozenset({'dessert'}), items_add=frozenset({'whole milk'}), confidence=0.1019830028328612, lift=0.645777262542574)]),
#  RelationRecord(items=frozenset({'detergent', 'rolls/buns'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({'detergent'}), items_add=frozenset({'rolls/buns'}), confidence=0.11627906976744186, lift=1.0570374975274803)]),
#  RelationRecord(items=frozenset({'detergent', 'whole milk'}), support=0.001403461872619127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'detergent'}), items_add=frozenset({'whole milk'}), confidence=0.1627906976744186, lift=1.0308240411774547)]),
#  RelationRecord(items=frozenset({'detergent', 'yogurt'}), support=0.0010693042839002875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'detergent'}), items_add=frozenset({'yogurt'}), confidence=0.12403100775193798, lift=1.4442614544686756)]),
#  RelationRecord(items=frozenset({'domestic eggs', 'whole milk'}), support=0.005279689901757669, ordered_statistics=[OrderedStatistic(items_base=frozenset({'domestic eggs'}), items_add=frozenset({'whole milk'}), confidence=0.14234234234234236, lift=0.9013408668931312)]),
#  RelationRecord(items=frozenset({'flour', 'tropical fruit'}), support=0.0010693042839002875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'flour'}), items_add=frozenset({'tropical fruit'}), confidence=0.10958904109589042, lift=1.6171408500175626)]),
#  RelationRecord(items=frozenset({'flour', 'whole milk'}), support=0.0013366303548753592, ordered_statistics=[OrderedStatistic(items_base=frozenset({'flour'}), items_add=frozenset({'whole milk'}), confidence=0.136986301369863, lift=0.8674253184076429)]),
#  RelationRecord(items=frozenset({'frankfurter', 'other vegetables'}), support=0.005146026866270133, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frankfurter'}), items_add=frozenset({'other vegetables'}), confidence=0.13628318584070798, lift=1.1161495948191098)]),
#  RelationRecord(items=frozenset({'frankfurter', 'whole milk'}), support=0.005279689901757669, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frankfurter'}), items_add=frozenset({'whole milk'}), confidence=0.13982300884955753, lift=0.8853879311959075)]),
#  RelationRecord(items=frozenset({'whole milk', 'frozen fish'}), support=0.0010693042839002875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen fish'}), items_add=frozenset({'whole milk'}), confidence=0.15686274509803924, lift=0.9932870312746345)]),
#  RelationRecord(items=frozenset({'other vegetables', 'frozen meals'}), support=0.002138608567800575, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen meals'}), items_add=frozenset({'other vegetables'}), confidence=0.12749003984063748, lift=1.0441343547539457)]),
#  RelationRecord(items=frozenset({'whole milk', 'frozen meals'}), support=0.0019381140145692708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen meals'}), items_add=frozenset({'whole milk'}), confidence=0.1155378486055777, lift=0.7316093223382392)]),
#  RelationRecord(items=frozenset({'frozen vegetables', 'other vegetables'}), support=0.003141081333957094, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen vegetables'}), items_add=frozenset({'other vegetables'}), confidence=0.11217183770883055, lift=0.9186793692595684)]),
#  RelationRecord(items=frozenset({'frozen vegetables', 'whole milk'}), support=0.003809396511394774, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen vegetables'}), items_add=frozenset({'whole milk'}), confidence=0.1360381861575179, lift=0.8614216586859672)]),
#  RelationRecord(items=frozenset({'fruit/vegetable juice', 'rolls/buns'}), support=0.003742564993651006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fruit/vegetable juice'}), items_add=frozenset({'rolls/buns'}), confidence=0.11001964636542241, lift=1.0001360683874942)]),
#  RelationRecord(items=frozenset({'fruit/vegetable juice', 'whole milk'}), support=0.004410880171088686, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fruit/vegetable juice'}), items_add=frozenset({'whole milk'}), confidence=0.12966601178781928, lift=0.8210717454003978)]),
#  RelationRecord(items=frozenset({'other vegetables', 'grapes'}), support=0.001603956425850431, ordered_statistics=[OrderedStatistic(items_base=frozenset({'grapes'}), items_add=frozenset({'other vegetables'}), confidence=0.1111111111111111, lift=0.9099920939001398)]),
#  RelationRecord(items=frozenset({'whole milk', 'grapes'}), support=0.0019381140145692708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'grapes'}), items_add=frozenset({'whole milk'}), confidence=0.13425925925925924, lift=0.8501571291986019)]),
#  RelationRecord(items=frozenset({'whole milk', 'ham'}), support=0.0027400922274944863, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ham'}), items_add=frozenset({'whole milk'}), confidence=0.16015624999999997, lift=1.0141421789039355)]),
#  RelationRecord(items=frozenset({'other vegetables', 'hamburger meat'}), support=0.002205440085544343, ordered_statistics=[OrderedStatistic(items_base=frozenset({'hamburger meat'}), items_add=frozenset({'other vegetables'}), confidence=0.10091743119266056, lift=0.8265065806982922)]),
#  RelationRecord(items=frozenset({'whole milk', 'hamburger meat'}), support=0.0030742498162133263, ordered_statistics=[OrderedStatistic(items_base=frozenset({'hamburger meat'}), items_add=frozenset({'whole milk'}), confidence=0.14067278287461774, lift=0.890768874377023)]),
#  RelationRecord(items=frozenset({'other vegetables', 'hard cheese'}), support=0.001670787943594199, ordered_statistics=[OrderedStatistic(items_base=frozenset({'hard cheese'}), items_add=frozenset({'other vegetables'}), confidence=0.11363636363636365, lift=0.9306737323978704)]),
#  RelationRecord(items=frozenset({'hard cheese', 'rolls/buns'}), support=0.001670787943594199, ordered_statistics=[OrderedStatistic(items_base=frozenset({'hard cheese'}), items_add=frozenset({'rolls/buns'}), confidence=0.11363636363636365, lift=1.0330139180382194)]),
#  RelationRecord(items=frozenset({'whole milk', 'hard cheese'}), support=0.001871282496825503, ordered_statistics=[OrderedStatistic(items_base=frozenset({'hard cheese'}), items_add=frozenset({'whole milk'}), confidence=0.1272727272727273, lift=0.8059169776478284)]),
#  RelationRecord(items=frozenset({'herbs', 'whole milk'}), support=0.0011361358016440553, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herbs'}), items_add=frozenset({'whole milk'}), confidence=0.10759493670886075, lift=0.6813131773062563)]),
#  RelationRecord(items=frozenset({'herbs', 'yogurt'}), support=0.0011361358016440553, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herbs'}), items_add=frozenset({'yogurt'}), confidence=0.10759493670886075, lift=1.2528739595133722)]),
#  RelationRecord(items=frozenset({'hygiene articles', 'other vegetables'}), support=0.001403461872619127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'hygiene articles'}), items_add=frozenset({'other vegetables'}), confidence=0.1024390243902439, lift=0.8389683207176899)]),
#  RelationRecord(items=frozenset({'hygiene articles', 'whole milk'}), support=0.0017376194613379669, ordered_statistics=[OrderedStatistic(items_base=frozenset({'hygiene articles'}), items_add=frozenset({'whole milk'}), confidence=0.12682926829268293, lift=0.8031089045549787)]),
#  RelationRecord(items=frozenset({'ice cream', 'rolls/buns'}), support=0.0017376194613379669, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ice cream'}), items_add=frozenset({'rolls/buns'}), confidence=0.11453744493392069, lift=1.0412052178288307)]),
#  RelationRecord(items=frozenset({'ice cream', 'whole milk'}), support=0.0019381140145692708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ice cream'}), items_add=frozenset({'whole milk'}), confidence=0.1277533039647577, lift=0.808960087695586)]),
#  RelationRecord(items=frozenset({'whole milk', 'long life bakery product'}), support=0.0024059346387756467, ordered_statistics=[OrderedStatistic(items_base=frozenset({'long life bakery product'}), items_add=frozenset({'whole milk'}), confidence=0.13432835820895522, lift=0.850594677901226)]),
#  RelationRecord(items=frozenset({'margarine', 'whole milk'}), support=0.0040767225823698456, ordered_statistics=[OrderedStatistic(items_base=frozenset({'margarine'}), items_add=frozenset({'whole milk'}), confidence=0.12655601659751037, lift=0.8013786188525382)]),
#  RelationRecord(items=frozenset({'meat', 'other vegetables'}), support=0.002138608567800575, ordered_statistics=[OrderedStatistic(items_base=frozenset({'meat'}), items_add=frozenset({'other vegetables'}), confidence=0.126984126984127, lift=1.0399909644573029)]),
#  RelationRecord(items=frozenset({'meat', 'whole milk'}), support=0.002205440085544343, ordered_statistics=[OrderedStatistic(items_base=frozenset({'meat'}), items_add=frozenset({'whole milk'}), confidence=0.13095238095238096, lift=0.8292172984301636)]),
#  RelationRecord(items=frozenset({'napkins', 'whole milk'}), support=0.0024059346387756467, ordered_statistics=[OrderedStatistic(items_base=frozenset({'napkins'}), items_add=frozenset({'whole milk'}), confidence=0.10876132930513596, lift=0.6886990141315064)]),
#  RelationRecord(items=frozenset({'whole milk', 'newspapers'}), support=0.005613847490476508, ordered_statistics=[OrderedStatistic(items_base=frozenset({'newspapers'}), items_add=frozenset({'whole milk'}), confidence=0.14432989690721648, lift=0.9139264694975372)]),
#  RelationRecord(items=frozenset({'oil', 'other vegetables'}), support=0.001804450979081735, ordered_statistics=[OrderedStatistic(items_base=frozenset({'oil'}), items_add=frozenset({'other vegetables'}), confidence=0.12107623318385649, lift=0.9916057346086725)]),
#  RelationRecord(items=frozenset({'oil', 'soda'}), support=0.001804450979081735, ordered_statistics=[OrderedStatistic(items_base=frozenset({'oil'}), items_add=frozenset({'soda'}), confidence=0.12107623318385649, lift=1.246843549298035)]),
#  RelationRecord(items=frozenset({'oil', 'whole milk'}), support=0.0019381140145692708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'oil'}), items_add=frozenset({'whole milk'}), confidence=0.13004484304932734, lift=0.8234705825421436)]),
#  RelationRecord(items=frozenset({'whole milk', 'onions'}), support=0.0029405867807257902, ordered_statistics=[OrderedStatistic(items_base=frozenset({'onions'}), items_add=frozenset({'whole milk'}), confidence=0.14521452145214522, lift=0.9195280933086962)]),
#  RelationRecord(items=frozenset({'pip fruit', 'other vegetables'}), support=0.004945532313038829, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pip fruit'}), items_add=frozenset({'other vegetables'}), confidence=0.10081743869209808, lift=0.8256876492336418)]),
#  RelationRecord(items=frozenset({'pork', 'other vegetables'}), support=0.00394305954688231, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pork'}), items_add=frozenset({'other vegetables'}), confidence=0.10630630630630632, lift=0.870641084434188)]),
#  RelationRecord(items=frozenset({'other vegetables', 'pot plants'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pot plants'}), items_add=frozenset({'other vegetables'}), confidence=0.1282051282051282, lift=1.0499908775770843)]),
#  RelationRecord(items=frozenset({'red/blush wine', 'other vegetables'}), support=0.0011361358016440553, ordered_statistics=[OrderedStatistic(items_base=frozenset({'red/blush wine'}), items_add=frozenset({'other vegetables'}), confidence=0.10828025477707005, lift=0.8868075819536394)]),
#  RelationRecord(items=frozenset({'salty snack', 'other vegetables'}), support=0.002205440085544343, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salty snack'}), items_add=frozenset({'other vegetables'}), confidence=0.11743772241992884, lift=0.96180659034997)]),
#  RelationRecord(items=frozenset({'other vegetables', 'semi-finished bread'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({'semi-finished bread'}), items_add=frozenset({'other vegetables'}), confidence=0.1056338028169014, lift=0.8651333287078794)]),
#  RelationRecord(items=frozenset({'shopping bags', 'other vegetables'}), support=0.004945532313038829, ordered_statistics=[OrderedStatistic(items_base=frozenset({'shopping bags'}), items_add=frozenset({'other vegetables'}), confidence=0.10393258426966293, lift=0.8512004698560297)]),
#  RelationRecord(items=frozenset({'soft cheese', 'other vegetables'}), support=0.0012029673193878234, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soft cheese'}), items_add=frozenset({'other vegetables'}), confidence=0.12000000000000001, lift=0.9827914614121511)]),
#  RelationRecord(items=frozenset({'specialty bar', 'other vegetables'}), support=0.001670787943594199, ordered_statistics=[OrderedStatistic(items_base=frozenset({'specialty bar'}), items_add=frozenset({'other vegetables'}), confidence=0.11961722488038277, lift=0.9796565604188109)]),
#  RelationRecord(items=frozenset({'other vegetables', 'specialty chocolate'}), support=0.001670787943594199, ordered_statistics=[OrderedStatistic(items_base=frozenset({'specialty chocolate'}), items_add=frozenset({'other vegetables'}), confidence=0.10460251046025104, lift=0.8566871176884162)]),
#  RelationRecord(items=frozenset({'white bread', 'other vegetables'}), support=0.0026064291920069507, ordered_statistics=[OrderedStatistic(items_base=frozenset({'white bread'}), items_add=frozenset({'other vegetables'}), confidence=0.10863509749303622, lift=0.8897137185486048)]),
#  RelationRecord(items=frozenset({'whole milk', 'other vegetables'}), support=0.014836596939116486, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables'}), items_add=frozenset({'whole milk'}), confidence=0.12151067323481116, lift=0.7694304712706219)]),
#  RelationRecord(items=frozenset({'packaged fruit/vegetables', 'rolls/buns'}), support=0.0012029673193878234, ordered_statistics=[OrderedStatistic(items_base=frozenset({'packaged fruit/vegetables'}), items_add=frozenset({'rolls/buns'}), confidence=0.14173228346456695, lift=1.2884205087972755)]),
#  RelationRecord(items=frozenset({'whole milk', 'pasta'}), support=0.0010693042839002875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'whole milk'}), confidence=0.1322314049586777, lift=0.8373163404133281)]),
#  RelationRecord(items=frozenset({'whole milk', 'pastry'}), support=0.006482657221145492, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pastry'}), items_add=frozenset({'whole milk'}), confidence=0.12532299741602068, lift=0.7935708888429613)]),
#  RelationRecord(items=frozenset({'whole milk', 'pickled vegetables'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pickled vegetables'}), items_add=frozenset({'whole milk'}), confidence=0.11194029850746269, lift=0.7088288982510217)]),
#  RelationRecord(items=frozenset({'pip fruit', 'rolls/buns'}), support=0.004945532313038829, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pip fruit'}), items_add=frozenset({'rolls/buns'}), confidence=0.10081743869209808, lift=0.9164831926791396)]),
#  RelationRecord(items=frozenset({'pip fruit', 'whole milk'}), support=0.006616320256633028, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pip fruit'}), items_add=frozenset({'whole milk'}), confidence=0.13487738419618528, lift=0.8540712229062719)]),
#  RelationRecord(items=frozenset({'whole milk', 'pork'}), support=0.005012363830782597, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pork'}), items_add=frozenset({'whole milk'}), confidence=0.13513513513513514, lift=0.8557033546453776)]),
#  RelationRecord(items=frozenset({'whole milk', 'pot plants'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pot plants'}), items_add=frozenset({'whole milk'}), confidence=0.1282051282051282, lift=0.8118211313302299)]),
#  RelationRecord(items=frozenset({'processed cheese', 'rolls/buns'}), support=0.0014702933903628951, ordered_statistics=[OrderedStatistic(items_base=frozenset({'processed cheese'}), items_add=frozenset({'rolls/buns'}), confidence=0.14473684210526316, lift=1.315733516659206)]),
#  RelationRecord(items=frozenset({'root vegetables', 'processed cheese'}), support=0.0010693042839002875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'processed cheese'}), items_add=frozenset({'root vegetables'}), confidence=0.10526315789473686, lift=1.5130188583851563)]),
#  RelationRecord(items=frozenset({'whole milk', 'processed cheese'}), support=0.0014702933903628951, ordered_statistics=[OrderedStatistic(items_base=frozenset({'processed cheese'}), items_add=frozenset({'whole milk'}), confidence=0.14473684210526316, lift=0.916503329843865)]),
#  RelationRecord(items=frozenset({'red/blush wine', 'rolls/buns'}), support=0.0013366303548753592, ordered_statistics=[OrderedStatistic(items_base=frozenset({'red/blush wine'}), items_add=frozenset({'rolls/buns'}), confidence=0.12738853503184713, lift=1.158028341240297)]),
#  RelationRecord(items=frozenset({'salty snack', 'rolls/buns'}), support=0.0019381140145692708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salty snack'}), items_add=frozenset({'rolls/buns'}), confidence=0.10320284697508897, lift=0.938167800296632)]),
#  RelationRecord(items=frozenset({'seasonal products', 'rolls/buns'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({'seasonal products'}), items_add=frozenset({'rolls/buns'}), confidence=0.14150943396226415, lift=1.2863946903872165)]),
#  RelationRecord(items=frozenset({'soft cheese', 'rolls/buns'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soft cheese'}), items_add=frozenset({'rolls/buns'}), confidence=0.1, lift=0.9090522478736331)]),
#  RelationRecord(items=frozenset({'whole milk', 'rolls/buns'}), support=0.013967787208447505, ordered_statistics=[OrderedStatistic(items_base=frozenset({'rolls/buns'}), items_add=frozenset({'whole milk'}), confidence=0.12697448359659783, lift=0.8040284376030019)]),
#  RelationRecord(items=frozenset({'root vegetables', 'whole milk'}), support=0.00755196150504578, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables'}), items_add=frozenset({'whole milk'}), confidence=0.10854947166186359, lift=0.6873574881406962)]),
#  RelationRecord(items=frozenset({'whole milk', 'salty snack'}), support=0.0019381140145692708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salty snack'}), items_add=frozenset({'whole milk'}), confidence=0.10320284697508897, lift=0.6535015655049752)]),
#  RelationRecord(items=frozenset({'whole milk', 'sausage'}), support=0.008955423377664907, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sausage'}), items_add=frozenset({'whole milk'}), confidence=0.14839424141749724, lift=0.9396627314134623)]),
#  RelationRecord(items=frozenset({'whole milk', 'semi-finished bread'}), support=0.001670787943594199, ordered_statistics=[OrderedStatistic(items_base=frozenset({'semi-finished bread'}), items_add=frozenset({'whole milk'}), confidence=0.176056338028169, lift=1.1148247930239072)]),
#  RelationRecord(items=frozenset({'shopping bags', 'whole milk'}), support=0.006348994185657956, ordered_statistics=[OrderedStatistic(items_base=frozenset({'shopping bags'}), items_add=frozenset({'whole milk'}), confidence=0.13342696629213482, lift=0.8448868796568826)]),
#  RelationRecord(items=frozenset({'whole milk', 'sliced cheese'}), support=0.0014702933903628951, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sliced cheese'}), items_add=frozenset({'whole milk'}), confidence=0.10476190476190475, lift=0.6633738387441307)]),
#  RelationRecord(items=frozenset({'whole milk', 'soda'}), support=0.011628684087415625, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soda'}), items_add=frozenset({'whole milk'}), confidence=0.11975223675154853, lift=0.7582956912879478)]),
#  RelationRecord(items=frozenset({'soft cheese', 'whole milk'}), support=0.0012029673193878234, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soft cheese'}), items_add=frozenset({'whole milk'}), confidence=0.12000000000000001, lift=0.7598645789250953)]),
#  RelationRecord(items=frozenset({'soft cheese', 'yogurt'}), support=0.0012697988371315912, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soft cheese'}), items_add=frozenset({'yogurt'}), confidence=0.12666666666666665, lift=1.4749520103761347)]),
#  RelationRecord(items=frozenset({'specialty bar', 'whole milk'}), support=0.001670787943594199, ordered_statistics=[OrderedStatistic(items_base=frozenset({'specialty bar'}), items_add=frozenset({'whole milk'}), confidence=0.11961722488038277, lift=0.757440768466004)]),
#  RelationRecord(items=frozenset({'whole milk', 'sugar'}), support=0.0024727661565194146, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sugar'}), items_add=frozenset({'whole milk'}), confidence=0.13962264150943396, lift=0.8841191641581297)]),
#  RelationRecord(items=frozenset({'whole milk', 'tropical fruit'}), support=0.008220276682483459, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tropical fruit'}), items_add=frozenset({'whole milk'}), confidence=0.121301775147929, lift=0.7681076857970638)]),
#  RelationRecord(items=frozenset({'waffles', 'whole milk'}), support=0.0026064291920069507, ordered_statistics=[OrderedStatistic(items_base=frozenset({'waffles'}), items_add=frozenset({'whole milk'}), confidence=0.14079422382671483, lift=0.891537863359769)]),
#  RelationRecord(items=frozenset({'whole milk', 'whipped/sour cream'}), support=0.004611374724319989, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream'}), items_add=frozenset({'whole milk'}), confidence=0.1055045871559633, lift=0.6680766557827672)]),
#  RelationRecord(items=frozenset({'white bread', 'whole milk'}), support=0.003141081333957094, ordered_statistics=[OrderedStatistic(items_base=frozenset({'white bread'}), items_add=frozenset({'whole milk'}), confidence=0.1309192200557103, lift=0.829007316840285)]),
#  RelationRecord(items=frozenset({'white wine', 'whole milk'}), support=0.0012697988371315912, ordered_statistics=[OrderedStatistic(items_base=frozenset({'white wine'}), items_add=frozenset({'whole milk'}), confidence=0.10857142857142857, lift=0.6874965237893719)]),
#  RelationRecord(items=frozenset({'whole milk', 'yogurt'}), support=0.011160863463209249, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt'}), items_add=frozenset({'whole milk'}), confidence=0.1299610894941634, lift=0.8229402378760758)]),
#  RelationRecord(items=frozenset({'soda', 'other vegetables', 'rolls/buns'}), support=0.0011361358016440553, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'rolls/buns'}), items_add=frozenset({'soda'}), confidence=0.10759493670886075, lift=1.108013102529032), OrderedStatistic(items_base=frozenset({'soda', 'other vegetables'}), items_add=frozenset({'rolls/buns'}), confidence=0.11724137931034483, lift=1.0657853940587423), OrderedStatistic(items_base=frozenset({'soda', 'rolls/buns'}), items_add=frozenset({'other vegetables'}), confidence=0.14049586776859505, lift=1.150651160055549)]),
#  RelationRecord(items=frozenset({'whole milk', 'other vegetables', 'rolls/buns'}), support=0.0012029673193878234, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'rolls/buns'}), items_add=frozenset({'whole milk'}), confidence=0.11392405063291139, lift=0.7213904230301538)]),
#  RelationRecord(items=frozenset({'soda', 'whole milk', 'other vegetables'}), support=0.0011361358016440553, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soda', 'other vegetables'}), items_add=frozenset({'whole milk'}), confidence=0.11724137931034483, lift=0.7423964276854379)]),
#  RelationRecord(items=frozenset({'whole milk', 'other vegetables', 'yogurt'}), support=0.0011361358016440553, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'yogurt'}), items_add=frozenset({'whole milk'}), confidence=0.14049586776859505, lift=0.8896486116891612), OrderedStatistic(items_base=frozenset({'whole milk', 'yogurt'}), items_add=frozenset({'other vegetables'}), confidence=0.10179640718562874, lift=0.8337053315372539)]),
#  RelationRecord(items=frozenset({'sausage', 'whole milk', 'rolls/buns'}), support=0.0011361358016440553, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sausage', 'rolls/buns'}), items_add=frozenset({'whole milk'}), confidence=0.2125, lift=1.345593525179856), OrderedStatistic(items_base=frozenset({'whole milk', 'sausage'}), items_add=frozenset({'rolls/buns'}), confidence=0.12686567164179105, lift=1.1532752398396837)]),
#  RelationRecord(items=frozenset({'whole milk', 'soda', 'rolls/buns'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soda', 'rolls/buns'}), items_add=frozenset({'whole milk'}), confidence=0.12396694214876033, lift=0.7849840691374952)]),
#  RelationRecord(items=frozenset({'whole milk', 'rolls/buns', 'yogurt'}), support=0.0013366303548753592, ordered_statistics=[OrderedStatistic(items_base=frozenset({'rolls/buns', 'yogurt'}), items_add=frozenset({'whole milk'}), confidence=0.17094017094017094, lift=1.0824281751069733), OrderedStatistic(items_base=frozenset({'whole milk', 'yogurt'}), items_add=frozenset({'rolls/buns'}), confidence=0.11976047904191618, lift=1.0886853267947703)]),
#  RelationRecord(items=frozenset({'whole milk', 'soda', 'sausage'}), support=0.0010693042839002875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soda', 'sausage'}), items_add=frozenset({'whole milk'}), confidence=0.17977528089887643, lift=1.138373901011379), OrderedStatistic(items_base=frozenset({'whole milk', 'sausage'}), items_add=frozenset({'soda'}), confidence=0.11940298507462688, lift=1.2296124333596987)]),
#  RelationRecord(items=frozenset({'whole milk', 'sausage', 'yogurt'}), support=0.0014702933903628951, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'sausage'}), items_add=frozenset({'yogurt'}), confidence=0.16417910447761194, lift=1.9117602648237413), OrderedStatistic(items_base=frozenset({'sausage', 'yogurt'}), items_add=frozenset({'whole milk'}), confidence=0.2558139534883721, lift=1.6198663504217148), OrderedStatistic(items_base=frozenset({'whole milk', 'yogurt'}), items_add=frozenset({'sausage'}), confidence=0.1317365269461078, lift=2.1829165589087607)])]

# %% [markdown]
# **Converting the results into DataFrame**

# %%
records = []
for rule in rules:
    for stat in rule.ordered_statistics:
        if len(stat.items_base) == 0:  # skip single-item rules
            continue
        records.append({
            'lhs': tuple(stat.items_base)[0],
            'rhs': tuple(stat.items_add)[0],
            'support': rule.support,
        })

df_rules = pd.DataFrame(records)
df_rules.head(15)
# Out:
#               lhs               rhs   support
# 0        UHT-milk  other vegetables  0.002139
# 1        UHT-milk        whole milk  0.002540
# 2            beef        whole milk  0.004678
# 3         berries  other vegetables  0.002673
# 4         berries        whole milk  0.002272
# 5       beverages  other vegetables  0.001738
# 6       beverages              soda  0.001871
# 7       beverages        whole milk  0.001938
# 8    bottled beer  other vegetables  0.004678
# 9    bottled beer        whole milk  0.007151
# 10  bottled water        whole milk  0.007151
# 11    brown bread        whole milk  0.004478
# 12         butter        whole milk  0.004678
# 13          candy        rolls/buns  0.001470
# 14          candy        whole milk  0.002139

# %% [markdown]
# # **Thank You!**
